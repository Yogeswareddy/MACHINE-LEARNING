# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#1a
df = pd.read_csv('/content/advertising.csv')

# %%
#1B
print("Mean of Radio-")
np.mean(df.Radio)
print("Mean of Newspaper-")
np.mean(df.Newspaper)
print("Mean of TV-")
np.median(df.TV)
# Out:
# Mean of Radio-
# Mean of Newspaper-
# Mean of TV-
# 149.75

# %%
#1b
print("mean of Radio:" )
np.mean(df.Radio)
# Out:
# mean of Radio:
# 23.264000000000006

# %%
#1b
print("Mean of Newspaper-")
np.mean(df.Newspaper)
# Out:
# Mean of Newspaper-
# 30.553999999999995

# %%
#1b
print("Median of TV-")
np.median(df.TV)
# Out:
# Median of TV-
# 149.75

# %%
#1c
df.Sales
# Out:
# 0      22.1
# 1      10.4
# 2      12.0
# 3      16.5
# 4      17.9
#        ...
# 195     7.6
# 196    14.0
# 197    14.8
# 198    25.5
# 199    18.4
# Name: Sales, Length: 200, dtype: float64

# %%
#1c
x=df.Sales
y=np.count(10.5<=x<=15.5)
y
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-82-842e41676dd2> in <module>
#       1 #1c
#       2 x=df.Sales
# ----> 3 y=np.count(10.5<=x<=15.5)
#       4 y
#
# /usr/local/lib/python3.7/dist-packages/numpy/__init__.py in __getattr__(attr)
#     312
#     313             raise AttributeError("module {!r} has no attribute "
# --> 314                                  "{!r}".format(__name__, attr))
#     315
#     316         def __dir__():
#
# AttributeError: module 'numpy' has no attribute 'count'

# %%
#1c
x=df.(Sales)
np.count(df.groupby(10.5<=x<=15.5))
# Out:
#   File "<ipython-input-77-d6e893ad82a0>", line 2
#     x=df.(Sales)
#          ^
# SyntaxError: invalid syntax

# %%
#2a first 8 instances
df.head(8)
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9
# 5    8.7   48.9       75.0    7.2
# 6   57.5   32.8       23.5   11.8
# 7  120.2   19.6       11.6   13.2

# %%
#2a Last 6 instances
df.tail(6)
# Out:
#         TV  Radio  Newspaper  Sales
# 194  149.7   35.6        6.0   17.3
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4

# %%
#2a Random 100 instances
import random
x = np.random.normal(df,100)
print(x)
# Out:
# [[ 3.60897251e+02  8.35997698e+01  9.95893564e+01  2.14187999e+01]
#  [ 4.21632109e+01  1.27341644e+01  8.88850023e+01 -1.08043712e+01]
#  [ 8.68830465e+01  1.50873003e+02  9.56740345e+01 -1.53555318e+02]
#  [ 2.21702482e+02 -2.88414900e+01 -1.11723719e+02  1.17644099e+01]
#  [ 8.90569187e+01  5.99457957e+01  6.10171953e+01  9.70300800e+01]
#  [ 8.32012198e+00  7.01240541e+01  1.39270523e+02  3.50257202e+00]
#  [ 4.44724589e+01  5.64028376e+01  1.40032456e+02 -2.61894755e+01]
#  [ 1.58231694e+01 -2.88145425e+01 -3.23840361e+00 -9.54326044e+01]
#  [ 1.70411343e+02 -1.86580456e+02 -2.81831959e+01  9.81704827e+01]
#  [ 2.06496683e+02  1.29814288e+02  4.40183115e+01  3.21377272e+01]
#  [ 1.23889611e+01 -9.83244826e+01  5.73442406e+01  5.02250133e+01]
#  [ 2.34598531e+02 -9.18289925e+01  8.13034550e+01  7.69670675e+01]
#  [ 1.03015232e+02  8.25282061e+01 -2.37494492e+01  6.53221481e+01]
#  [ 1.04069901e+02 -1.63565848e+02 -5.87433148e+01 -2.25338952e+00]
# ...

# %%
#2b
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
#2c
df.describe
# Out:
# <bound method NDFrame.describe of         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]>

# %%
#2d
df.isnull()
# Out:
#         TV  Radio  Newspaper  Sales
# 0    False  False      False  False
# 1    False  False      False  False
# 2    False  False      False  False
# 3    False  False      False  False
# 4    False  False      False  False
# ..     ...    ...        ...    ...
# 195  False  False      False  False
# 196  False  False      False  False
# 197  False  False      False  False
# 198  False  False      False  False
# 199  False  False      False  False
#
# [200 rows x 4 columns]

# %%
#2d
df.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
#3a
sns.pairplot(df)

# %%
#3b
sns.lmplot(x ='TV', y='Sales', data=df)
sns.lmplot(x ='Radio', y='Sales', data=df)
sns.lmplot(x ='Newspaper', y='Sales', data=df)

# %%
#3b
sns.lmplot(x ='Newspaper', y='TV', data=df)
sns.lmplot(x ='Radio', y='TV', data=df)
sns.lmplot(x ='Sales', y='TV', data=df)

# %%
#3b
sns.lmplot(x ='TV', y='Radio', data=df)
sns.lmplot(x ='Sales', y='Radio', data=df)
sns.lmplot(x ='Newspaper', y='Radio', data=df)

# %%
#3b
sns.lmplot(x ='TV', y='Newspaper', data=df)
sns.lmplot(x ='Radio', y='Newspaper', data=df)
sns.lmplot(x ='Sales', y='Newspaper', data=df)

# %%
#3c bin=50
sns.distplot(df.Sales,bins=50)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#3c bin=70
sns.distplot(df.Sales,bins=70)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#4a
X=df['TV']
y=df['Sales']

# %%
#4b
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split (X,y, test_size=0.2,random_state=100)
X_train,X_test =X_train.values ,X_test.values
X_train =X_train.reshape(-1,1)
X_test =X_test.reshape(-1,1)

# %%
#4c
from sklearn.linear_model import LinearRegression
lm =LinearRegression()
lm.fit(X_train,y_train)
predictions=lm.predict(X_test)
plt.scatter(y_test ,predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
#4d
X_mean = np.mean(X)
y_mean = np.mean(y)
num = 0
den = 0
for i in range(len(X)):
    num += (X[i] - X_mean)*(y[i] - y_mean)
    den += (X[i] - X_mean)**2
m = num / den
c = y_mean - m*X_mean
print (m, c)
# Out:
# 0.05546477046955879 6.974821488229903

# %%
#4e
from sklearn import metrics 
print('MAE:' , metrics.mean_absolute_error(y_test,predictions))
print('MSE:' , metrics.mean_squared_error(y_test , predictions))
print('RMSE:' , np.sqrt(metrics.mean_squared_error(y_test ,predictions)))
# Out:
# MAE: 1.905152391298234
# MSE: 5.34850349246385
# RMSE: 2.312683180304611

# %%
#5a
y1=df['Sales']
X1=df[['TV','Radio','Newspaper']]
from sklearn.model_selection import train_test_split
X1_train,X1_test,y1_train,y1_test = train_test_split (X1,y1, test_size=0.2,random_state=100)

# %%
#5a
from sklearn.linear_model import LinearRegression
lm =LinearRegression()
lm.fit(X1_train,y1_train)
predictions=lm.predict(X1_test)
plt.scatter(y1_test ,predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
#5a
X_mean = np.mean(X)
y_mean = np.mean(y)
num = 0
den = 0
for i in range(len(X)):
    num += (X[i] - X_mean)*(y[i] - y_mean)
    den += (X[i] - X_mean)**2
m = num / den
c = y_mean - m*X_mean
print (m, c)
# Out:
# 0.05546477046955879 6.974821488229903

# %%
#5a
from sklearn import metrics 
print('MAE:' , metrics.mean_absolute_error(y_test,predictions))
print('MSE:' , metrics.mean_squared_error(y_test , predictions))
print('RMSE:' , np.sqrt(metrics.mean_squared_error(y_test ,predictions)))
# Out:
# MAE: 1.4149258169276047
# MSE: 3.3509887213291796
# RMSE: 1.8305705999303004

# %%
#5b

# %% [markdown]
# In SLR there will be only one input variable where as in MLR there will be more than 1 input variable.
# Whereas both SLR and MLR has 1 output variable.
# The given data set contains 3 input and 1 output variables.
